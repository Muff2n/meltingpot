# %%
from ray import tune
import os
import pandas as pd
import logging
logging.disable(logging.CRITICAL)

# The commons_harvest optimisation results have been lost

# 6cd22b0f easily the best
INPUT = os.path.abspath("optimise/experiment_state_externality_mushrooms__dense.json")

# 419fddae and 85e9ce73 are my preferred runs, I will interpolate their parameters
INPUT = os.path.abspath("optimise/experiment_state_territory__inside_out.json")

INPUT = "/scratch_tmp/users/k21075402/tf_2_15_2/territory__inside_out/optimise/experiment_state-2024-11-25_16-49-47.json"

# %%
def format_df(df):
    df = df.rename(columns={'env_runners/episode_reward_mean': 'episode_reward_mean'})
    df['time_total_s'] = df['time_total_s'].fillna(0).astype(int)
    df['episode_reward_mean'] = df['episode_reward_mean'].round()
    cols = ['episode_reward_mean', 'training_iteration', 'timesteps_total', 'time_total_s', 'config/lr', 'config/lambda', 'config/clip_param', 'config/vf_clip_param', 
            'config/vf_loss_coeff', 'config/entropy_coeff', 'config/sgd_minibatch_size', 'config/num_sgd_iter']
    df = df[cols].sort_values(['episode_reward_mean'], ascending=False)
    df = df.dropna()
    return df

# %%
df = tune.ExperimentAnalysis(INPUT).results_df
df = format_df(df)

pd.concat([df.head(10), df.tail(5)])
# Out:
#           episode_reward_mean  training_iteration  timesteps_total  \
# trial_id
# c57c84ec                766.0                 150          9000000
# e977060c                706.0                 135          8100000
# 8cab63f2                698.0                 150          9000000
# 61b1b3e3                638.0                 150          9000000
# 88be7305                632.0                 150          9000000
# 947ace64                619.0                 150          9000000
# 38619070                618.0                 150          9000000
# bc6f779a                616.0                 150          9000000
# 69eb2488                608.0                 150          9000000
# 3deca9c6                603.0                 150          9000000
# abf0c62a                105.0                  75          4500000
# 4904a386                 87.0                  75          4500000
# c33f763a                 61.0                  75          4500000
# f55942bc                 57.0                  75          4500000
# 14a4cd06                 38.0                  75          4500000
#
#           time_total_s  config/lr  config/lambda  config/clip_param  \
# trial_id
# c57c84ec         17519   0.000051           0.75               0.20
# e977060c         14950   0.000108           0.85               0.25
# 8cab63f2         17272   0.000034           1.00               0.10
# 61b1b3e3         18734   0.000051           0.90               0.15
# 88be7305         17610   0.000073           0.90               0.20
# 947ace64         21441   0.000043           0.80               0.25
# 38619070         19257   0.000047           0.90               0.15
# bc6f779a         16907   0.000072           0.85               0.25
# 69eb2488         17235   0.002473           1.00               0.10
# 3deca9c6         18879   0.000045           1.00               0.15
# abf0c62a          8816   0.000054           0.75               0.20
# 4904a386          8742   0.000051           0.75               0.20
# c33f763a          8633   0.001197           0.85               0.25
# f55942bc          8470   0.000071           0.80               0.25
# 14a4cd06          8189   0.000038           0.85               0.10
#
#           config/vf_clip_param  config/vf_loss_coeff  config/entropy_coeff  \
# trial_id
# c57c84ec                    16                   0.9                 0.001
# e977060c                    12                   0.7                 0.001
# 8cab63f2                    14                   0.7                 0.001
# 61b1b3e3                    10                   0.6                 0.001
# 88be7305                     8                   0.6                 0.001
# 947ace64                    14                   1.0                 0.001
# 38619070                    10                   0.6                 0.001
# bc6f779a                     8                   1.0                 0.001
# 69eb2488                    14                   0.7                 0.001
# 3deca9c6                    10                   0.6                 0.001
# abf0c62a                    16                   0.9                 0.001
# 4904a386                    16                   0.9                 0.001
# c33f763a                     4                   0.4                 0.001
# f55942bc                     8                   0.7                 0.001
# 14a4cd06                     8                   0.7                 0.001
#
#           config/sgd_minibatch_size  config/num_sgd_iter
# trial_id
# c57c84ec                       2500                    6
# e977060c                       2500                    6
# 8cab63f2                       5000                    6
# 61b1b3e3                       7500                    8
# 88be7305                       2500                    6
# 947ace64                       7500                   12
# 38619070                       2500                    8
# bc6f779a                       2500                    6
# 69eb2488                       7500                    6
# 3deca9c6                       7500                    8
# abf0c62a                       2500                    6
# 4904a386                       2500                    6
# c33f763a                       5000                    6
# f55942bc                       2500                    6
# 14a4cd06                      10000                    6
